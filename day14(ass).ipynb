# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\shrey\Downloads\Day_13_Pharma_data.csv")

# %%
df
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# 3             88             4     50-60    12 months
# 4             70             1     30-40     3 months
# 5             82             3     40-50     6 months
# 6             86             5     20-30     6 months
# 7             78             2     30-40     3 months
# 8             80             4     50-60    12 months
# 9             90             6     20-30     6 months

# %%
df.isnull().sum()
# Out:
# Product_ID         0
# Product_Name       0
# Region             0
# Marketing_Spend    0
# Sales              0
# Effectiveness      0
# Side_Effects       0
# Age_Group          0
# Trial_Period       0
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# 3             88             4     50-60    12 months
# 4             70             1     30-40     3 months
# 5             82             3     40-50     6 months
# 6             86             5     20-30     6 months
# 7             78             2     30-40     3 months
# 8             80             4     50-60    12 months
# 9             90             6     20-30     6 months

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# 3             88             4     50-60    12 months
# 4             70             1     30-40     3 months
# 5             82             3     40-50     6 months
# 6             86             5     20-30     6 months
# 7             78             2     30-40     3 months
# 8             80             4     50-60    12 months
# 9             90             6     20-30     6 months

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\shrey\Downloads\Day_13_Pharma_data.csv")
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)
data
# Out:
#    Product_ID Product_Name         Region  Marketing_Spend   Sales  \
# 0         101   PainRelief  North America            50000  100000
# 1         102     ColdCure         Europe            30000   60000
# 2         103  HeadacheFix           Asia            45000   80000
# 3         104   PainRelief  North America            52000  110000
# 4         105     ColdCure         Europe            28000   55000
# 5         106  HeadacheFix           Asia            48000   90000
# 6         107   PainRelief  North America            51000  105000
# 7         108     ColdCure         Europe            31000   65000
# 8         109  HeadacheFix           Asia            47000   85000
# 9         110   PainRelief  North America            53000  115000
#
#    Effectiveness  Side_Effects Age_Group Trial_Period
# 0             85             5     20-30     6 months
# 1             75             2     30-40     3 months
# 2             80             3     40-50     6 months
# 3             88             4     50-60    12 months
# 4             70             1     30-40     3 months
# 5             82             3     40-50     6 months
# 6             86             5     20-30     6 months
# 7             78             2     30-40     3 months
# 8             80             4     50-60    12 months
# 9             90             6     20-30     6 months

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Effectiveness', hue='Product_Name', data=data, ci=None)
plt.title('Average Effectiveness of Drugs Across Regions')
plt.xlabel('Region')
plt.ylabel('Average Effectiveness')
plt.legend(title='Drug')
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_16324\1142768571.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Region', y='Effectiveness', hue='Product_Name', data=data, ci=None)

# %%
plt.figure(figsize=(14, 7))
sns.violinplot(x='Product_Name', y='Effectiveness', data=data, inner='quartile', color='skyblue')
plt.title('Distribution of Effectiveness for Each Product')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.violinplot(x='Product_Name', y='Side_Effects', data=data, inner='quartile', color='lightgreen')
plt.title('Distribution of Side Effects for Each Product')
plt.show()

# %%
sns.pairplot(data, vars=['Effectiveness', 'Side_Effects', 'Marketing_Spend'], hue='Product_Name', height=2.5)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Trial_Period', y='Effectiveness', data=data, palette='coolwarm')
plt.title('Effectiveness Across Trial Periods')
plt.xlabel('Trial Period')
plt.ylabel('Effectiveness')
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_16324\857414573.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Trial_Period', y='Effectiveness', data=data, palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Marketing_Spend', y='Effectiveness', data=data, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Effect of Marketing Spend on Drug Effectiveness')
plt.xlabel('Marketing Spend')
plt.ylabel('Effectiveness')
plt.show()

# %%
print(data[['Effectiveness', 'Side_Effects']].corr())
# Out:
#                Effectiveness  Side_Effects
# Effectiveness       1.000000      0.916819
# Side_Effects        0.916819      1.000000
